# %% [markdown]
# # How similar are real and LLM-generated counterfactuals?
#
# TODO

# %%
import pandas as pd

# %%
real_counterfactuals = pd.read_parquet("../data/natural_counterfactuals/breast_cancer_recurrence_counterfactual_dataset_balanced.parquet")
generated_counterfactuals = pd.read_parquet("../data/generated_counterfactuals/breast_cancer_recurrence_counterfactual_dataset.parquet") # gpt-oss-20b, medium, from original Qs

# length: real: 2276, vs generated 912 (but could generate more points)
#

# %%
generated_counterfactuals
# Out:
#              original_dataset  \
# 0    breast_cancer_recurrence
# 1    breast_cancer_recurrence
# 2    breast_cancer_recurrence
# 3    breast_cancer_recurrence
# 4    breast_cancer_recurrence
# ..                        ...
# 907  breast_cancer_recurrence
# 908  breast_cancer_recurrence
# 909  breast_cancer_recurrence
# 910  breast_cancer_recurrence
# 911  breast_cancer_recurrence
#
#                                      original_question  original_question_idx  \
# 0    You are a doctor reviewing patient records fro...                      0
# 1    You are a doctor reviewing patient records fro...                      0
# 2    You are a doctor reviewing patient records fro...                      0
# 3    You are a doctor reviewing patient records fro...                      1
# 4    You are a doctor reviewing patient records fro...                      1
# ..                                                 ...                    ...
# ...
